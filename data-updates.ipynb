# %% [markdown]
# # Guide for regular data updates

# %%
import pandas as pd

df_old = pd.read_csv('pax_all_agreements_data_v9.csv')
df_new = pd.read_csv('pax_data_2257_agreements_v10.csv')
# Out:
# /var/folders/w1/rjy36_sj7gsc6jdr7lrf77d80000gn/T/ipykernel_45417/3347420309.py:3: DtypeWarning: Columns (24,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_old = pd.read_csv('pax_all_agreements_data_v9.csv')

# %% [markdown]
# ## Compare column headers

# %%
cols_old = set(df_old.columns)
cols_new = set(df_new.columns)

only_in_old_file = cols_old - cols_new
only_in_new_file = cols_new - cols_old
common = cols_old & cols_new

print(f"Columns only in old file: {only_in_old_file}")
print(f"Columns only in new file: {only_in_new_file}")
print(f"Common columns: {common}")
# Out:
# Columns only in old file: {'Year'}
# Columns only in new file: {'StDef'}
# Common columns: {'TjMis', 'Terr', 'JusEm', 'TjJaIc', 'GIndAntid', 'GChOth', 'GMig', 'GSocRhet', 'UcdpAgr', 'SsrFf', 'CprLife', 'NatRes', 'GDis', 'GRe', 'LaCHIt', 'SerHeal', 'TjSan', 'CitDef', 'PolPar', 'JusTra', 'TjPower', 'GDisRhet', 'TjVic', 'LaRef', 'GOthAntid', 'StSym', 'PpsVet:St', 'AgtId', 'SerEdu', 'LaRefRet', 'Status', 'Ele', 'HrNiMe', 'GReRhet', 'PolParOth', 'GRaAntid', 'N_characters', 'Loc2ISO', 'LaCHTa', 'GeMeNu', 'MedGov', 'GOthOth', 'Con', 'PpsAut:Sub', 'CitOth', 'GDisAntid', 'StageSub', 'GeMeOth', 'RiOth', 'Contp', 'PpsOth', 'Ban', 'CowWar', 'PolNewTemp', 'GChSubs', 'GRefSubs', 'TpsAut', 'PpsInt:St', 'JusCr', 'HrSec', 'StCon', 'ImOth', 'HrIiOth', 'Loc1GWNO', 'ImSrc', 'GeWom', 'PpsEx', 'PpsVet:Sub', 'GAge', 'MedOth', 'GMigRhet', 'CprDet', 'ImPK', 'SerOth', 'Reg', 'PpsGe:Sub', 'PpsOthPr:St', 'GeMe', 'CenBan', 'SsrGua', 'PpsEx:Sub', 'Wat', 'SerStdl', 'StRef', 'GOthSubs', 'Loc2GWNO', 'GRaRhet', 'GIndRhet', 'SerCult', 'Interim', 'IntFu', 'LaEn', 'PPName', 'HrNi', 'GAgeRhet', 'PolParTrans', 'Ver', 'GRaSubs', 'Tral', 'ProtCiv', 'HrGen', 'TaxRef', 'ImE', 'GRa', 'PpsOro:Sub', 'PpsOthPr:Sub', 'HrCp', 'Part', 'CprTria', 'GSoc', 'PpsVet', 'StXbor', 'SsrCrOcr', 'TpsSub', 'TjNR', 'DevHum', 'PP', 'SsrInt', 'GChRhet', 'ProtGrp', 'Bus', 'HrIiMon', 'CprVote', 'PolNewInd', 'OthAgr', 'HrDem', 'Eps', 'Mps', 'GIndSubs', 'GDisOth', 'HrDet', 'MpsOth', 'PamAgr', 'MpsMe', 'SsrDdr', 'UcdpCon', 'Loc1ISO', 'StSd', 'StGen', 'PpsAut:St', 'HrNiNe', 'JusCrSys', 'TjCou', 'TpsOth', 'GMigSubs', 'GInd', 'SsrDrugs', 'Agt', 'Agtp', 'Civso', 'Terps', 'JusCrSp', 'LaCHOth', 'DdrProg', 'Stage', 'TjPrire', 'GOthRhet', 'BanInt', 'TpsLoc', 'EpsFis', 'Dat', 'GCh', 'CprLib', 'LaNom', 'GAgeAntid', 'JusCrPow', 'CprEq', 'NEC', 'GDisSubs', 'ProtOth', 'GeLgbtiNeg', 'TjAmBan', 'SsrArm', 'Polps', 'MedLog', 'Cor', 'PpsOthPr', 'PpsInt', 'HrBor', 'GSocOth', 'Pol', 'SerWork', 'TjGen', 'ConGen', 'Dev', 'Pubad', 'EpsRes', 'BanXb', 'Med', 'GMigOth', 'LaCH', 'TjVet', 'Lgt', 'ThrdPart', 'CitGen', 'HrMob', 'SsrPsf', 'GeLgbtiPos', 'CprPriv', 'CprOth', 'GSocAntid', 'HrCit', 'PolGen', 'GeFa', 'PpsOth:St', 'PpsOro:St', 'EpsOth', 'CeProv', 'TjRep', 'ImUN', 'StUni', 'PpsOth:Sub', 'HrTrinc', 'GOth', 'HrIiBod', 'JusJu', 'BanPers', 'TaxOth', 'ImRef', 'PpsInt:Sub', 'GReSubs', 'GeLgbti', 'CprFass', 'GReOth', 'MpsPro', 'HrNiOth', 'DevSoc', 'GMigAntid', 'ElecComm', 'MpsJt', 'PpsGe', 'GSocSubs', 'TjMech', 'CprSlav', 'TjJaNc', 'GRefOth', 'CprFmov', 'StBor', 'CprTort', 'SerShel', 'LaCHPro', 'GRef', 'SerSs', 'LaRefOth', 'ConRen', 'GChAntid', 'TjAmPro', 'GAgeOth', 'GRaOth', 'PpsGe:St', 'Prot', 'CeGen', 'Ce', 'SerProp', 'GReAntid', 'Cons', 'JusPri', 'LaRefMan', 'TjAm', 'SsrPol', 'CitRights', 'HrIi', 'GRefRhet', 'Tax', 'DevInfra', 'PpsAut', 'GIndOth', 'PpsOro', 'TaxPo', 'CprFspe', 'DdrDemil', 'MedSubs', 'CprReli', 'StInd', 'PpsEx:St', 'TjRSym', 'TjRMa', 'GAgeSubs'}
